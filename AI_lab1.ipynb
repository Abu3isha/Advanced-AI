# %% [markdown]
# <a href="https://colab.research.google.com/github/Abu3isha/Advanced-AI/blob/main/AI_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

a=1 #coefficient of x^2
b=2 #coefficient of x
c=3 #coefficient tern

def quadratic_function(x):
  return a * x**2 +b *x + c

x_vertex = -b /(2*a)
y_vertex = quadratic_function(x_vertex)

x_values = np.linspace(x_vertx-10, x_vertx+10, 400)
y_values = quadratic_function(x_values)


plt.plot(x_values, y_values, label=f'f(x) = {a} x^2 + {b} x +{c}')
plt.scatter(x_vertex, y_vertex, color = 'red', label= f'{"Minimum" if a > 0 else "Maximum"} at ({x_vertex:.2f}, {y_vertex:.2f})')
plt.title("Quadratic function plot")
plt.legend()
plt.grid(True)
plt.show()
print
